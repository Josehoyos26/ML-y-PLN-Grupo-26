# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Redes Neuronales
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de redes neuronales de una capa y multicapa. El taller está constituido por 4 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción probabilidad de admisión a la universidad
#
# En este taller se usará el conjunto de datos de admisiones a una universidad proveniente de la base de datos de Kaggle. Cada observación contiene la probabilidad de que un estudiante sea admitido por la universidad, dadas distintas variables predictoras como el puntaje del examén TOEFL y GRE, el promedio (GPA), entre otras. El objetivo es predecir la probabilidad de admissión de cada estudiante. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/mohansacharya/graduate-admissions).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import numpy as np
import keras 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras import initializers
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Dropout
from keras import backend as K
from livelossplot import PlotLossesKeras
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Carga de datos de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/universityGraduateAdmissions.csv', index_col=0)
data.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
# Hitogramas de las varaibles del dataset
data.hist(bins=25, figsize=(15,15))
plt.show()

# %%
# Definición de variables predictoras (X)
X = data.drop(data.columns[-1], axis=1)
# Definición de variable de interés (y)
Y = data[data.columns[-1]]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# %% [markdown]
# ## Punto 1 - Red Neuronal de una capa
#
# En la celda 1 creen una **red neuronal de una capa** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes, usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador y el número de épocas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Normalización de variables predictoras (X) con la función StandardScaler

# Definición de la función StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Transformación de los set de entrenamiento y test
X_train = pd.DataFrame(data=scaler.transform(xTrain), columns=xTrain.columns, index=xTrain.index)
X_test = pd.DataFrame(data=scaler.transform(xTest), columns=xTest.columns, index=xTest.index)

X_train = np.array(X_train)
Y_train = pd.DataFrame(data=yTrain, index=yTrain.index)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = pd.DataFrame(data=yTest, index=yTest.index)
Y_test = np.array(yTest)

# %%
# Definición de dimensiones de salida, varaibles de interés
#Y_train = np.array(Y_train)
output_var = Y_train.shape[1]
print(output_var, ' output variables')
# Out:
# 1  output variables

# %%
# Definición de dimensiones de entrada, varibles predictoras
dims = X_train.shape[1]
print(dims, 'input variables')
# Out:
# 7 input variables

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model_nn_unicapa = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model_nn_unicapa.add(Dense(output_var, input_shape=(dims,)))

# Impresión de la arquitectura de la red neuronal
print(model_nn_unicapa.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 8
#
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model_nn_unicapa.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Sub-Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_trainn, X_val, Y_trainn, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# Entrenamiento de la red neuronal con 100 épocas
model_nn_unicapa.fit(X_trainn, Y_trainn, 
          verbose=1, 
          epochs=100, 
          validation_data=(X_val, Y_val),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.004, max:    0.951, cur:    0.004)
# 	validation       	 (min:    0.004, max:    0.890, cur:    0.004)
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0041 - val_loss: 0.0043

# %%
# Evaluación del modelo
y_pred = model_nn_unicapa.predict(X_test)
mse_nn_unicapa1 = mean_squared_error(Y_test, y_pred)   
mae_nn_unicapa1 = mean_absolute_error(Y_test, y_pred)   
print('Error absoluto medio (MAE):', mae_nn_unicapa1)
print('Error cuadrático medio (MSE):', mse_nn_unicapa1)
# Out:
# 5/5 [==============================] - 0s 5ms/step
# Error absoluto medio (MAE): 0.042962890291213994
# Error cuadrático medio (MSE): 0.003219462521322056

# %% [markdown]
# Después de la sub-separación de datos de entrenamiento para considerar un set de validación y así evitar overfitting nos damos cuenta que la gráfica de la pérdida del modelo vs las épocas se comienzan a estabilizar después de la época 40-60. Con un MSE en entrenamiento de 0.0038 y en validación de 0.0037.
#
# Luego, cuando evaluamos la predicción del modelo con la muestra test, nos damos cuenta que el valor MAE es de 0.04 y el MSE es del 0.0033, relativamente cerca a los valores observados con la muestra de validación. Es decir, el modelo se comporta bien prediciendo datos nuevos.

# %% [markdown]
# #### Usamos función earlystop

# %% [markdown]
# Para salir de dudas, usamos una función earlystop para evaluar hasta que época hay pérdida y usamos la función ModelCheckpoint para guardar el modelo con el mejor desempeño. Después de evaluar los optimizadores En este caso si la pérdida en validación (monitor="val_loss") no cambia por 2 períodos o por 2 épocas (patience=2), este le dice al algoritmo que no se entrene más.

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model_nn_unicapa1 = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model_nn_unicapa1.add(Dense(output_var, input_shape=(dims,)))
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model_nn_unicapa1.compile(optimizer='sgd', loss='mean_absolute_error')

# %%
# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# Definición de la función ModelCheckpoint para guardar el modelo con mejor desempeño
fBestModel = 'best_model_mae_una_capa.h5'
best_model = ModelCheckpoint(fBestModel,verbose=0,save_best_only=True)

# %% [markdown]
# Las redes neuronales pueden hacer muy facilmente overfitting con los datos de entrenamiento. Por lo que hacer split con data de validación, permite calibrar hiperparametros de la red y así hacer que el algoritmo logre generalizar todos los casos posibles.

# %%
# Sub-Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_trainn, X_val, Y_trainn, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# Entrenamiento de la red neuronal con 80 épocas y early stopping
model_nn_unicapa1.fit(X_trainn, Y_trainn, 
          epochs=200, 
          batch_size=128,
          validation_data=(X_val, Y_val),
          callbacks=[PlotLossesKeras(),best_model, early_stop])
# Out:
# Loss
# 	training         	 (min:    0.042, max:    1.102, cur:    0.044)
# 	validation       	 (min:    0.044, max:    1.142, cur:    0.045)
# 3/3 [==============================] - 0s 145ms/step - loss: 0.0444 - val_loss: 0.0449
# Epoch 89: early stopping

# %%
# Evaluación del modelo
y_pred = model_nn_unicapa1.predict(X_test)
mse_nn_unicapa2 = mean_squared_error(Y_test, y_pred)   
mae_nn_unicapa2 = mean_absolute_error(Y_test, y_pred)   
print('Error absoluto medio (MAE):', mae_nn_unicapa2)
print('Error cuadrático medio (MSE):', mse_nn_unicapa2)
# Out:
# 5/5 [==============================] - 0s 4ms/step
# Error absoluto medio (MAE): 0.04059429131348928
# Error cuadrático medio (MSE): 0.0034695947999998688

# %% [markdown]
# Cuando usamos early_stop con un modelo sgd y una función de pérdida MAE el modelo se estabiliza por los lados de la época 140. El MAE en entrenamiento es del 0.047 y en validación 0.045.
# Cuando medimos la predicción del modelo en la muestra test, el error absoluto medio MAE nos da un valor de 0.045, una medida relativamente cerca al valor en validación por lo que confirmamos que el modelo no presenta overfitting.

# %% [markdown]
# ## Punto 2 - Red Neuronal multicapa
#
# En la celda 2 creen una **red neuronal con dos capas** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 2
# Normalización de los datos
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usando la función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X, Y, test_size=0.3, random_state=22)

# Creación del modelo de red neuronal
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(7,)))  # Capa oculta con 64 neuronas y función de activación ReLU
model.add(Dense(32, activation='relu'))  # Capa oculta con 32 neuronas y función de activación ReLU
model.add(Dense(1, activation='sigmoid'))  # Capa de salida con 1 neurona y función de activación sigmoidal

# Compilación del modelo
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])

# Entrenamiento del modelo
history = model.fit(xTrain, yTrain, validation_data=(xTest, yTest), epochs=100, batch_size=32, verbose=1)

# Evaluación del modelo
loss, mae, mse = model.evaluate(xTest, yTest, verbose=0)
print('Error absoluto medio (MAE):', mae)
print('Error cuadrático medio (MSE):', mse)

# Gráfica de pérdida vs número de épocas

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Pérdida del modelo')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend(['Entrenamiento', 'Validación'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 14ms/step - loss: 0.0398 - mae: 0.1662 - mse: 0.0398 - val_loss: 0.0208 - val_mae: 0.1232 - val_mse: 0.0208
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0119 - mae: 0.0907 - mse: 0.0119 - val_loss: 0.0082 - val_mae: 0.0695 - val_mse: 0.0082
# Epoch 3/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0059 - mae: 0.0597 - mse: 0.0059 - val_loss: 0.0062 - val_mae: 0.0618 - val_mse: 0.0062
# Epoch 4/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0054 - mae: 0.0571 - mse: 0.0054 - val_loss: 0.0061 - val_mae: 0.0611 - val_mse: 0.0061
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0050 - mae: 0.0535 - mse: 0.0050 - val_loss: 0.0060 - val_mae: 0.0592 - val_mse: 0.0060
# Epoch 6/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0045 - mae: 0.0511 - mse: 0.0045 - val_loss: 0.0056 - val_mae: 0.0579 - val_mse: 0.0056
# Epoch 7/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0043 - mae: 0.0498 - mse: 0.0043 - val_loss: 0.0055 - val_mae: 0.0570 - val_mse: 0.0055
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0041 - mae: 0.0486 - mse: 0.0041 - val_loss: 0.0052 - val_mae: 0.0554 - val_mse: 0.0052
# Epoch 9/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0039 - mae: 0.0472 - mse: 0.0039 - val_loss: 0.0050 - val_mae: 0.0533 - val_mse: 0.0050
# Epoch 10/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0038 - mae: 0.0464 - mse: 0.0038 - val_loss: 0.0048 - val_mae: 0.0523 - val_mse: 0.0048
# Epoch 11/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0037 - mae: 0.0454 - mse: 0.0037 - val_loss: 0.0047 - val_mae: 0.0514 - val_mse: 0.0047
# Epoch 12/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0035 - mae: 0.0443 - mse: 0.0035 - val_loss: 0.0045 - val_mae: 0.0504 - val_mse: 0.0045
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0035 - mae: 0.0436 - mse: 0.0035 - val_loss: 0.0045 - val_mae: 0.0500 - val_mse: 0.0045
# Epoch 14/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0034 - mae: 0.0437 - mse: 0.0034 - val_loss: 0.0044 - val_mae: 0.0494 - val_mse: 0.0044
# Epoch 15/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0033 - mae: 0.0421 - mse: 0.0033 - val_loss: 0.0043 - val_mae: 0.0479 - val_mse: 0.0043
# Epoch 16/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032 - val_loss: 0.0042 - val_mae: 0.0477 - val_mse: 0.0042
# Epoch 17/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031 - val_loss: 0.0042 - val_mae: 0.0473 - val_mse: 0.0042
# Epoch 18/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031 - val_loss: 0.0041 - val_mae: 0.0470 - val_mse: 0.0041
# Epoch 19/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0398 - mse: 0.0030 - val_loss: 0.0041 - val_mae: 0.0465 - val_mse: 0.0041
# Epoch 20/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0030 - mae: 0.0399 - mse: 0.0030 - val_loss: 0.0040 - val_mae: 0.0465 - val_mse: 0.0040
# Epoch 21/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029 - val_loss: 0.0039 - val_mae: 0.0459 - val_mse: 0.0039
# Epoch 22/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0388 - mse: 0.0029 - val_loss: 0.0040 - val_mae: 0.0457 - val_mse: 0.0040
# Epoch 23/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - mae: 0.0379 - mse: 0.0028 - val_loss: 0.0039 - val_mae: 0.0453 - val_mse: 0.0039
# Epoch 24/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0028 - mae: 0.0382 - mse: 0.0028 - val_loss: 0.0039 - val_mae: 0.0453 - val_mse: 0.0039
# Epoch 25/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028 - val_loss: 0.0039 - val_mae: 0.0459 - val_mse: 0.0039
# Epoch 26/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0027 - mae: 0.0374 - mse: 0.0027 - val_loss: 0.0040 - val_mae: 0.0457 - val_mse: 0.0040
# Epoch 27/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0027 - mae: 0.0369 - mse: 0.0027 - val_loss: 0.0039 - val_mae: 0.0448 - val_mse: 0.0039
# Epoch 28/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0026 - mae: 0.0365 - mse: 0.0026 - val_loss: 0.0038 - val_mae: 0.0454 - val_mse: 0.0038
# Epoch 29/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0026 - mae: 0.0366 - mse: 0.0026 - val_loss: 0.0039 - val_mae: 0.0449 - val_mse: 0.0039
# Epoch 30/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0026 - mae: 0.0361 - mse: 0.0026 - val_loss: 0.0038 - val_mae: 0.0457 - val_mse: 0.0038
# Epoch 31/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026 - val_loss: 0.0042 - val_mae: 0.0467 - val_mse: 0.0042
# Epoch 32/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0025 - mae: 0.0357 - mse: 0.0025 - val_loss: 0.0038 - val_mae: 0.0455 - val_mse: 0.0038
# Epoch 33/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0025 - mae: 0.0364 - mse: 0.0025 - val_loss: 0.0041 - val_mae: 0.0453 - val_mse: 0.0041
# Epoch 34/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0025 - mae: 0.0355 - mse: 0.0025 - val_loss: 0.0038 - val_mae: 0.0454 - val_mse: 0.0038
# Epoch 35/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0024 - mae: 0.0351 - mse: 0.0024 - val_loss: 0.0039 - val_mae: 0.0450 - val_mse: 0.0039
# Epoch 36/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0024 - mae: 0.0347 - mse: 0.0024 - val_loss: 0.0039 - val_mae: 0.0451 - val_mse: 0.0039
# Epoch 37/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0024 - mae: 0.0348 - mse: 0.0024 - val_loss: 0.0039 - val_mae: 0.0452 - val_mse: 0.0039
# Epoch 38/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0024 - mae: 0.0344 - mse: 0.0024 - val_loss: 0.0038 - val_mae: 0.0454 - val_mse: 0.0038
# Epoch 39/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0023 - mae: 0.0344 - mse: 0.0023 - val_loss: 0.0040 - val_mae: 0.0454 - val_mse: 0.0040
# Epoch 40/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0023 - mae: 0.0340 - mse: 0.0023 - val_loss: 0.0039 - val_mae: 0.0458 - val_mse: 0.0039
# Epoch 41/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.
100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0019 - mae: 0.0311 - mse: 0.0019 - val_loss: 0.0043 - val_mae: 0.0470 - val_mse: 0.0043
# Epoch 64/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0019 - mae: 0.0305 - mse: 0.0019 - val_loss: 0.0040 - val_mae: 0.0469 - val_mse: 0.0040
# Epoch 65/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0300 - mse: 0.0018 - val_loss: 0.0042 - val_mae: 0.0469 - val_mse: 0.0042
# Epoch 66/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0300 - mse: 0.0018 - val_loss: 0.0041 - val_mae: 0.0466 - val_mse: 0.0041
# Epoch 67/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0298 - mse: 0.0018 - val_loss: 0.0040 - val_mae: 0.0466 - val_mse: 0.0040
# Epoch 68/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0301 - mse: 0.0018 - val_loss: 0.0042 - val_mae: 0.0469 - val_mse: 0.0042
# Epoch 69/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0298 - mse: 0.0018 - val_loss: 0.0041 - val_mae: 0.0468 - val_mse: 0.0041
# Epoch 70/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0291 - mse: 0.0017 - val_loss: 0.0042 - val_mae: 0.0469 - val_mse: 0.0042
# Epoch 71/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0293 - mse: 0.0017 - val_loss: 0.0041 - val_mae: 0.0465 - val_mse: 0.0041
# Epoch 72/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0298 - mse: 0.0017 - val_loss: 0.0045 - val_mae: 0.0485 - val_mse: 0.0045
# Epoch 73/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0292 - mse: 0.0017 - val_loss: 0.0041 - val_mae: 0.0487 - val_mse: 0.0041
# Epoch 74/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0302 - mse: 0.0018 - val_loss: 0.0044 - val_mae: 0.0475 - val_mse: 0.0044
# Epoch 75/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0303 - mse: 0.0017 - val_loss: 0.0042 - val_mae: 0.0467 - val_mse: 0.0042
# Epoch 76/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0290 - mse: 0.0017 - val_loss: 0.0042 - val_mae: 0.0487 - val_mse: 0.0042
# Epoch 77/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0301 - mse: 0.0018 - val_loss: 0.0042 - val_mae: 0.0473 - val_mse: 0.0042
# Epoch 78/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0286 - mse: 0.0016 - val_loss: 0.0041 - val_mae: 0.0468 - val_mse: 0.0041
# Epoch 79/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0284 - mse: 0.0016 - val_loss: 0.0043 - val_mae: 0.0477 - val_mse: 0.0043
# Epoch 80/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0016 - mae: 0.0281 - mse: 0.0016 - val_loss: 0.0041 - val_mae: 0.0471 - val_mse: 0.0041
# Epoch 81/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0286 - mse: 0.0016 - val_loss: 0.0043 - val_mae: 0.0472 - val_mse: 0.0043
# Epoch 82/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0285 - mse: 0.0016 - val_loss: 0.0041 - val_mae: 0.0474 - val_mse: 0.0041
# Epoch 83/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0281 - mse: 0.0016 - val_loss: 0.0042 - val_mae: 0.0474 - val_mse: 0.0042
# Epoch 84/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0278 - mse: 0.0016 - val_loss: 0.0043 - val_mae: 0.0473 - val_mse: 0.0043
# Epoch 85/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0280 - mse: 0.0016 - val_loss: 0.0044 - val_mae: 0.0480 - val_mse: 0.0044
# Epoch 86/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0280 - mse: 0.0016 - val_loss: 0.0042 - val_mae: 0.0479 - val_mse: 0.0042
# Epoch 87/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - mae: 0.0278 - mse: 0.0016 - val_loss: 0.0043 - val_mae: 0.0476 - val_mse: 0.0043
# Epoch 88/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0279 - mse: 0.0015 - val_loss: 0.0042 - val_mae: 0.0474 - val_mse: 0.0042
# Epoch 89/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0275 - mse: 0.0015 - val_loss: 0.0043 - val_mae: 0.0475 - val_mse: 0.0043
# Epoch 90/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0273 - mse: 0.0015 - val_loss: 0.0042 - val_mae: 0.0480 - val_mse: 0.0042
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0275 - mse: 0.0015 - val_loss: 0.0042 - val_mae: 0.0476 - val_mse: 0.0042
# Epoch 92/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0015 - mae: 0.0272 - mse: 0.0015 - val_loss: 0.0044 - val_mae: 0.0481 - val_mse: 0.0044
# Epoch 93/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0276 - mse: 0.0015 - val_loss: 0.0044 - val_mae: 0.0481 - val_mse: 0.0044
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0271 - mse: 0.0015 - val_loss: 0.0044 - val_mae: 0.0494 - val_mse: 0.0044
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0280 - mse: 0.0016 - val_loss: 0.0043 - val_mae: 0.0477 - val_mse: 0.0043
# Epoch 96/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0269 - mse: 0.0014 - val_loss: 0.0043 - val_mae: 0.0478 - val_mse: 0.0043
# Epoch 97/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0272 - mse: 0.0014 - val_loss: 0.0042 - val_mae: 0.0484 - val_mse: 0.0042
# Epoch 98/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0268 - mse: 0.0014 - val_loss: 0.0044 - val_mae: 0.0480 - val_mse: 0.0044
# Epoch 99/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0271 - mse: 0.0014 - val_loss: 0.0046 - val_mae: 0.0491 - val_mse: 0.0046
# Epoch 100/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0272 - mse: 0.0015 - val_loss: 0.0043 - val_mae: 0.0489 - val_mse: 0.0043
# Error absoluto medio (MAE): 0.0489005446434021
# Error cuadrático medio (MSE): 0.004296514671295881

# %%
# Evaluación del modelo
y_pred = model.predict(X_test)
mse_nn_multi2_bas = mean_squared_error(Y_test, y_pred)   
mae_nn_multi2_bas = mean_absolute_error(Y_test, y_pred)   
print('Error absoluto medio (MAE):', mae_nn_multi2_bas)
print('Error cuadrático medio (MSE):', mse_nn_multi2_bas)
# Out:
# 5/5 [==============================] - 0s 5ms/step
# Error absoluto medio (MAE): 0.04890054089228312
# Error cuadrático medio (MSE): 0.004296514303933027

# %% [markdown]
# En primer lugar el modelo se define utilizando la clase Sequential de Keras. Esta clase permite construir modelos de manera secuencial, agregando capas una encima de la otra.
# La primera capa oculta se agrega utilizando el método add del modelo. Es una capa densamente conectada (Dense) con 64 neuronas. La función de activación utilizada es ReLU (activation='relu'). La capa recibe una entrada de tamaño (7,), ya que se espera que los datos de entrada tengan 7 características.
# La segunda capa oculta también es una capa densamente conectada (Dense) con 32 neuronas y función de activación ReLU. No es necesario especificar el tamaño de entrada en esta capa, ya que Keras puede inferirlo automáticamente a partir de la capa anterior.
# La capa de salida es una capa densamente conectada (Dense) con 1 neurona. Se utiliza una función de activación sigmoidal (activation='sigmoid') en la capa de salida, que es adecuada para problemas de clasificación binaria donde se desea predecir una probabilidad.
# Después de definir la arquitectura del modelo. Luego El parámetro loss='mean_squared_error' especifica que se utilizará el error cuadrático medio como función de pérdida, que es adecuada para problemas de regresión.
# El optimizador utilizado es Adam (optimizer='adam'), que es un algoritmo de optimización popular y eficiente para entrenar redes neuronales.
# Se especifica la métrica a utilizar durante el entrenamiento, que en este caso son el error absoluto medio (mae) y el error cuadrático medio (mse).
# Finalmente, el modelo se entrena utilizando los datos de entrenamiento y validación, y se evalúa utilizando los datos de prueba. El historial del entrenamiento se almacena en la variable history, y se muestra el error absoluto medio y el error cuadrático medio obtenidos en los datos de prueba.
# El redultado arrojado indica overfitting debido a que la pérdida en el conjunto de datos de entrenamiento es más baja que la pérdida en el conjunto de datos de validación. Para superar esta situación se plantea las siguientes opciones:
# 1.	Regularización: Agregar términos de regularización a las capas ocultas de tu modelo puede ayudar a reducir el sobreajuste.
# 2.	Dropout: El dropout es una técnica que consiste en desactivar aleatoriamente algunas neuronas durante el entrenamiento para evitar el sobreajuste.
# 3.	Ajuste de hiperparámetros.
# A continuación presentaremos los resultados explorando todos los casos.

# %% [markdown]
# ## Regularización
#
# Hemos agregado kernel_regularizer=regularizers.l2(0.01) a las capas ocultas. El argumento kernel_regularizer toma un objeto de regularización de Keras. En este caso, estamos utilizando regularizers.l2, que implementa la regularización L2.
# El valor 0.01 que se pasa a regularizers.l2 es el parámetro de regularización, también conocido como lambda. Este valor controla la cantidad de penalización aplicada a los pesos en las capas ocultas.
# Al aplicar la regularización L2, estás agregando una penalización a la función de pérdida proporcional a la magnitud al cuadrado de los pesos. Esto ayuda a controlar los valores de los pesos y puede reducir el riesgo de sobreajuste al desalentar el crecimiento excesivo de los pesos.

# %%
from keras import regularizers

# Normalización de los datos
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# Creación del modelo con regularización L2
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(7,), kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(1, activation='sigmoid'))

# Compilación del modelo
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])

# Entrenamiento del modelo
history = model.fit(xTrain, yTrain, validation_data=(xTest, yTest), epochs=100, batch_size=32, verbose=1)

# Evaluación del modelo
loss, mae, mse = model.evaluate(xTest, yTest, verbose=0)
print('Error absoluto medio (MAE):', mae)
print('Error cuadrático medio (MSE):', mse)

# Gráfica de pérdida vs número de épocas

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Pérdida del modelo')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend(['Entrenamiento', 'Validación'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 14ms/step - loss: 0.5964 - mae: 0.2220 - mse: 0.0613 - val_loss: 0.5395 - val_mae: 0.1607 - val_mse: 0.0308
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0
100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0081 - mae: 0.0536 - mse: 0.0049 - val_loss: 0.0076 - val_mae: 0.0500 - val_mse: 0.0044
# Epoch 68/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0527 - mse: 0.0046 - val_loss: 0.0076 - val_mae: 0.0487 - val_mse: 0.0042
# Epoch 69/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0528 - mse: 0.0047 - val_loss: 0.0076 - val_mae: 0.0503 - val_mse: 0.0044
# Epoch 70/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0538 - mse: 0.0047 - val_loss: 0.0076 - val_mae: 0.0488 - val_mse: 0.0043
# Epoch 71/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0528 - mse: 0.0047 - val_loss: 0.0075 - val_mae: 0.0496 - val_mse: 0.0043
# Epoch 72/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0537 - mse: 0.0047 - val_loss: 0.0075 - val_mae: 0.0487 - val_mse: 0.0042
# Epoch 73/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0080 - mae: 0.0518 - mse: 0.0047 - val_loss: 0.0074 - val_mae: 0.0490 - val_mse: 0.0043
# Epoch 74/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0548 - mse: 0.0048 - val_loss: 0.0074 - val_mae: 0.0497 - val_mse: 0.0043
# Epoch 75/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0522 - mse: 0.0048 - val_loss: 0.0075 - val_mae: 0.0487 - val_mse: 0.0043
# Epoch 76/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0538 - mse: 0.0047 - val_loss: 0.0073 - val_mae: 0.0500 - val_mse: 0.0042
# Epoch 77/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0523 - mse: 0.0047 - val_loss: 0.0074 - val_mae: 0.0483 - val_mse: 0.0043
# Epoch 78/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0078 - mae: 0.0529 - mse: 0.0046 - val_loss: 0.0073 - val_mae: 0.0490 - val_mse: 0.0042
# Epoch 79/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0078 - mae: 0.0525 - mse: 0.0046 - val_loss: 0.0073 - val_mae: 0.0488 - val_mse: 0.0042
# Epoch 80/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0530 - mse: 0.0047 - val_loss: 0.0073 - val_mae: 0.0491 - val_mse: 0.0042
# Epoch 81/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0526 - mse: 0.0046 - val_loss: 0.0072 - val_mae: 0.0492 - val_mse: 0.0041
# Epoch 82/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0537 - mse: 0.0046 - val_loss: 0.0072 - val_mae: 0.0486 - val_mse: 0.0041
# Epoch 83/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0519 - mse: 0.0046 - val_loss: 0.0072 - val_mae: 0.0483 - val_mse: 0.0042
# Epoch 84/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0522 - mse: 0.0046 - val_loss: 0.0072 - val_mae: 0.0487 - val_mse: 0.0041
# Epoch 85/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0533 - mse: 0.0046 - val_loss: 0.0072 - val_mae: 0.0480 - val_mse: 0.0041
# Epoch 86/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0522 - mse: 0.0048 - val_loss: 0.0072 - val_mae: 0.0491 - val_mse: 0.0043
# Epoch 87/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0077 - mae: 0.0539 - mse: 0.0047 - val_loss: 0.0071 - val_mae: 0.0483 - val_mse: 0.0041
# Epoch 88/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0514 - mse: 0.0045 - val_loss: 0.0071 - val_mae: 0.0477 - val_mse: 0.0040
# Epoch 89/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0520 - mse: 0.0046 - val_loss: 0.0070 - val_mae: 0.0496 - val_mse: 0.0041
# Epoch 90/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0523 - mse: 0.0046 - val_loss: 0.0071 - val_mae: 0.0474 - val_mse: 0.0041
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0526 - mse: 0.0046 - val_loss: 0.0070 - val_mae: 0.0495 - val_mse: 0.0041
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0075 - mae: 0.0521 - mse: 0.0046 - val_loss: 0.0071 - val_mae: 0.0478 - val_mse: 0.0041
# Epoch 93/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0076 - mae: 0.0516 - mse: 0.0046 - val_loss: 0.0070 - val_mae: 0.0500 - val_mse: 0.0040
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0075 - mae: 0.0536 - mse: 0.0047 - val_loss: 0.0071 - val_mae: 0.0484 - val_mse: 0.0043
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0075 - mae: 0.0516 - mse: 0.0046 - val_loss: 0.0069 - val_mae: 0.0484 - val_mse: 0.0040
# Epoch 96/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0075 - mae: 0.0522 - mse: 0.0045 - val_loss: 0.0069 - val_mae: 0.0478 - val_mse: 0.0040
# Epoch 97/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0075 - mae: 0.0520 - mse: 0.0046 - val_loss: 0.0069 - val_mae: 0.0487 - val_mse: 0.0041
# Epoch 98/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0075 - mae: 0.0522 - mse: 0.0046 - val_loss: 0.0069 - val_mae: 0.0476 - val_mse: 0.0040
# Epoch 99/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0074 - mae: 0.0513 - mse: 0.0045 - val_loss: 0.0068 - val_mae: 0.0489 - val_mse: 0.0040
# Epoch 100/100
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0074 - mae: 0.0525 - mse: 0.0046 - val_loss: 0.0069 - val_mae: 0.0480 - val_mse: 0.0040
# Error absoluto medio (MAE): 0.047992657870054245
# Error cuadrático medio (MSE): 0.004045487381517887

# %%
# Evaluación del modelo
y_pred = model.predict(X_test)
mse_nn_multi2_reg = mean_squared_error(Y_test, y_pred)   
mae_nn_multi2_reg = mean_absolute_error(Y_test, y_pred)   
print('Error absoluto medio (MAE):', mae_nn_multi2_reg)
print('Error cuadrático medio (MSE):', mse_nn_multi2_reg)
# Out:
# 5/5 [==============================] - 0s 3ms/step
# Error absoluto medio (MAE): 0.04799266072909037
# Error cuadrático medio (MSE): 0.004045486907738607

# %% [markdown]
# ## Droput
#
# En esta situación hemos agregado capas de Dropout después de las capas ocultas. El valor 0.2 que se pasa a Dropout representa la fracción de las neuronas que se desactivarán aleatoriamente durante el entrenamiento.
# Durante el entrenamiento, las neuronas desactivadas se omiten temporalmente, lo que reduce su contribución a la propagación hacia adelante y hacia atrás. Esto obliga a las neuronas restantes a aprender de manera más robusta y a no depender en exceso de un subconjunto particular de neuronas. Como resultado, el Dropout puede ayudar a reducir el sobreajuste y mejorar la generalización del modelo.
# Es importante tener en cuenta que durante la inferencia o evaluación del modelo, todas las neuronas están activas para aprovechar al máximo la capacidad del modelo. El Dropout solo se aplica durante el entrenamiento.

# %%
from keras.layers import Dropout
# Normalización de los datos
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# Creación del modelo con dropout
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(7,)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compilación del modelo
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])

# Entrenamiento del modelo
history = model.fit(xTrain, yTrain, validation_data=(xTest, yTest), epochs=100, batch_size=32, verbose=1)

# Evaluación del modelo
loss, mae, mse = model.evaluate(xTest, yTest, verbose=0)
print('Error absoluto medio (MAE):', mae)
print('Error cuadrático medio (MSE):', mse)

# Gráfica de pérdida vs número de épocas

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Pérdida del modelo')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend(['Entrenamiento', 'Validación'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 13ms/step - loss: 0.1080 - mae: 0.2745 - mse: 0.1080 - val_loss: 0.0623 - val_mae: 0.2089 - val_mse: 0.0623
# Epoch 2/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0684 - mae: 0.2143 - mse: 0.0684 - val_loss: 0.0335 - val_mae: 0.1558 - val_mse: 0.0335
# Epoch 3/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0349 - mae: 0.1550 - mse: 0.0349 - val_loss: 0.0183 - val_mae: 0.1136 - val_mse: 0.0183
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0240 - mae: 0.1210 - mse: 0.0240 - val_loss: 0.0114 - val_mae: 0.0829 - val_mse: 0.0114
# Epoch 5/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0177 - mae: 0.1038 - mse: 0.0177 - val_loss: 0.0085 - val_mae: 0.0664 - val_mse: 0.0085
# Epoch 6/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0162 - mae: 0.1010 - mse: 0.0162 - val_loss: 0.0066 - val_mae: 0.0578 - val_mse: 0.0066
# Epoch 7/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0121 - mae: 0.0874 - mse: 0.0121 - val_loss: 0.0060 - val_mae: 0.0564 - val_mse: 0.0060
# Epoch 8/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0128 - mae: 0.0867 - mse: 0.0128 - val_loss: 0.0057 - val_mae: 0.0561 - val_mse: 0.0057
# Epoch 9/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0126 - mae: 0.0894 - mse: 0.0126 - val_loss: 0.0056 - val_mae: 0.0561 - val_mse: 0.0056
# Epoch 10/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0121 - mae: 0.0860 - mse: 0.0121 - val_loss: 0.0056 - val_mae: 0.0563 - val_mse: 0.0056
# Epoch 11/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0120 - mae: 0.0839 - mse: 0.0120 - val_loss: 0.0055 - val_mae: 0.0564 - val_mse: 0.0055
# Epoch 12/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0106 - mae: 0.0823 - mse: 0.0106 - val_loss: 0.0055 - val_mae: 0.0566 - val_mse: 0.0055
# Epoch 13/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0116 - mae: 0.0851 - mse: 0.0116 - val_loss: 0.0054 - val_mae: 0.0565 - val_mse: 0.0054
# Epoch 14/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0100 - mae: 0.0802 - mse: 0.0100 - val_loss: 0.0053 - val_mae: 0.0562 - val_mse: 0.0053
# Epoch 15/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0094 - mae: 0.0784 - mse: 0.0094 - val_loss: 0.0052 - val_mae: 0.0561 - val_mse: 0.0052
# Epoch 16/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0097 - mae: 0.0794 - mse: 0.0097 - val_loss: 0.0052 - val_mae: 0.0558 - val_mse: 0.0052
# Epoch 17/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0094 - mae: 0.0775 - mse: 0.0094 - val_loss: 0.0052 - val_mae: 0.0554 - val_mse: 0.0052
# Epoch 18/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0104 - mae: 0.0814 - mse: 0.0104 - val_loss: 0.0052 - val_mae: 0.0552 - val_mse: 0.0052
# Epoch 19/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.
100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0059 - mae: 0.0591 - mse: 0.0059 - val_loss: 0.0047 - val_mae: 0.0501 - val_mse: 0.0047
# Epoch 86/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0066 - mae: 0.0635 - mse: 0.0066 - val_loss: 0.0046 - val_mae: 0.0499 - val_mse: 0.0046
# Epoch 87/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0062 - mae: 0.0612 - mse: 0.0062 - val_loss: 0.0046 - val_mae: 0.0500 - val_mse: 0.0046
# Epoch 88/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0613 - mse: 0.0063 - val_loss: 0.0046 - val_mae: 0.0500 - val_mse: 0.0046
# Epoch 89/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0054 - mae: 0.0587 - mse: 0.0054 - val_loss: 0.0046 - val_mae: 0.0497 - val_mse: 0.0046
# Epoch 90/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0619 - mse: 0.0063 - val_loss: 0.0046 - val_mae: 0.0498 - val_mse: 0.0046
# Epoch 91/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0065 - mae: 0.0622 - mse: 0.0065 - val_loss: 0.0046 - val_mae: 0.0498 - val_mse: 0.0046
# Epoch 92/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0060 - mae: 0.0597 - mse: 0.0060 - val_loss: 0.0046 - val_mae: 0.0500 - val_mse: 0.0046
# Epoch 93/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0059 - mae: 0.0598 - mse: 0.0059 - val_loss: 0.0045 - val_mae: 0.0497 - val_mse: 0.0045
# Epoch 94/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0057 - mae: 0.0575 - mse: 0.0057 - val_loss: 0.0045 - val_mae: 0.0492 - val_mse: 0.0045
# Epoch 95/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0604 - mse: 0.0063 - val_loss: 0.0044 - val_mae: 0.0490 - val_mse: 0.0044
# Epoch 96/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0057 - mae: 0.0578 - mse: 0.0057 - val_loss: 0.0044 - val_mae: 0.0492 - val_mse: 0.0044
# Epoch 97/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0062 - mae: 0.0626 - mse: 0.0062 - val_loss: 0.0044 - val_mae: 0.0490 - val_mse: 0.0044
# Epoch 98/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0059 - mae: 0.0596 - mse: 0.0059 - val_loss: 0.0044 - val_mae: 0.0487 - val_mse: 0.0044
# Epoch 99/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0051 - mae: 0.0556 - mse: 0.0051 - val_loss: 0.0044 - val_mae: 0.0486 - val_mse: 0.0044
# Epoch 100/100
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0618 - mse: 0.0063 - val_loss: 0.0044 - val_mae: 0.0488 - val_mse: 0.0044
# Error absoluto medio (MAE): 0.04882349073886871
# Error cuadrático medio (MSE): 0.004373717587441206

# %%
# Evaluación del modelo
y_pred = model.predict(X_test)
mse_nn_multi2_do = mean_squared_error(Y_test, y_pred)   
mae_nn_multi2_do = mean_absolute_error(Y_test, y_pred)   
print('Error absoluto medio (MAE):', mae_nn_multi2_do)
print('Error cuadrático medio (MSE):', mse_nn_multi2_do)
# Out:
# 5/5 [==============================] - 0s 1ms/step
# Error absoluto medio (MAE): 0.048823491684595745
# Error cuadrático medio (MSE): 0.004373717819994988

# %% [markdown]
# ## Ajuste hiperparametros
#
# Utilizamos la función create_model para construir el modelo de red neuronal con diferentes combinaciones de hiperparámetros. Luego, envolvemos el modelo en KerasRegressor para que sea compatible con la búsqueda en cuadrícula de scikit-learn.
# Definimos un diccionario param_grid que contiene los hiperparámetros que queremos buscar. En este ejemplo, buscamos diferentes optimizadores (adam y sgd), funciones de activación (relu y sigmoid) y números de neuronas (32, 64, 128).
# Luego, utilizamos GridSearchCV para realizar la búsqueda en cuadrícula. Especificamos el estimador (nuestro modelo envuelto en KerasRegressor), el diccionario de hiperparámetros y el número de divisiones en la validación cruzada (cv). El objeto grid realizará la búsqueda exhaustiva de todas las combinaciones posibles de hiperparámetros y seleccionará la mejor combinación.
# Finalmente, imprimimos los mejores resultados obtenidos, que incluyen el puntaje (best_score_) y los mejores hiperparámetros (best_params_).

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# Normalización de los datos
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# Función para construir el modelo
def create_model(optimizer='adam', activation='relu', neurons=64):
    model = Sequential()
    model.add(Dense(neurons, activation=activation, input_shape=(7,)))
    model.add(Dense(neurons, activation=activation))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mae', 'mse'])
    return model

# Crear el modelo envuelto en KerasRegressor
model = KerasRegressor(build_fn=create_model, verbose=0)

# Definir los hiperparámetros para buscar
param_grid = {
    'optimizer': ['adam', 'sgd'],
    'activation': ['relu', 'sigmoid'],
    'neurons': [32, 64, 128]
}

# Realizar la búsqueda en cuadrícula
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
grid_result = grid.fit(xTrain, yTrain)

# Mostrar los mejores resultados
print("Mejor: %f utilizando %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Mejor: -0.016132 utilizando {'activation': 'relu', 'neurons': 128, 'optimizer': 'adam'}

# %% [markdown]
# ## Sub-dividimos la muestra entrenamiento para obtener muestra validación

# %%
# Mejores hiperparámetros encontrados
best_optimizer = grid_result.best_params_['optimizer']
best_activation = grid_result.best_params_['activation']
best_neurons = grid_result.best_params_['neurons']

K.clear_session()
# Sub-Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_trainn, X_val, Y_trainn, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# Creación del modelo de red neuronal
model_nn_multi2 = Sequential()
model_nn_multi2.add(Dense(64, activation='relu', input_shape=(dims,)))  # Capa oculta con 64 neuronas y función de activación ReLU
model_nn_multi2.add(Dense(32, activation='relu'))  # Capa oculta con 32 neuronas y función de activación ReLU
model_nn_multi2.add(Dense(1, activation='sigmoid'))  # Capa de salida con 1 neurona y función de activación sigmoidal

# Compilación del modelo
model_nn_multi2.compile(loss='mean_squared_error', optimizer=best_optimizer)

# Entrenamiento del modelo
history = model_nn_multi2.fit(X_trainn, Y_trainn, 
                    validation_data=(X_val, Y_val), 
                    epochs=50, 
                    batch_size=32, 
                    callbacks=[PlotLossesKeras()],
                    verbose=1)
# Out:
# Loss
# 	training         	 (min:    0.002, max:    0.048, cur:    0.002)
# 	validation       	 (min:    0.004, max:    0.024, cur:    0.004)
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0040

# %%
# Evaluación del modelo
y_pred = model_nn_multi2.predict(X_test)
mse_nn_multi2 = mean_squared_error(Y_test, y_pred)   
mae_nn_multi2 = mean_absolute_error(Y_test, y_pred)   
print('Error absoluto medio (MAE):', mae_nn_multi2)
print('Error cuadrático medio (MSE):', mse_nn_multi2)
# Out:
# 5/5 [==============================] - 0s 5ms/step
# Error absoluto medio (MAE): 0.04743145332336426
# Error cuadrático medio (MSE): 0.004145793407985652

# %% [markdown]
# Es inquietante que esta última gráfica, cuando subdividimos la muestra entrenamiento en una muestra de validación la función de pérdida vs épocas nunca se estabiliza, por lo que para este modelo no recomendamos usar este método para combatir el overfitting.

# %% [markdown]
# Teniendo en cuenta los reultados obtenidos anteriormente, la técnica que arrojó los mejores resultados en relación a la corrección del sobreajuste es la de "regularización".
# Error absoluto medio (MAE): 0.04799266072909037
# Error cuadrático medio (MSE): 0.004045486907738607

# %% [markdown]
# ## Punto 3  - Red Neuronal multicapa
#
# En la celda 3 creen **una red neuronal con más de una capa con la librería Keras, usando early stopping y dropout,** que prediga la probabilidad de admisión de los estudiantes con los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %% [markdown]
# ### Primera configuración graficando la funcion de perdida en base al MSE (_Error Cuadratico Medio_)
#
# En esta primera configuración de multicapa, definimos un modelo secuencial como en los puntos anteriores, y vamos adicionando las capas respectivas de la red una a una.
#
# Con una funcion de activación de tipo _'relu'_, que permite normalizar en 0 los valores negativos ya que estamos trabajando con valores de salida entre 0 y 1. Agregamos una capa densa de entrada con 10 neuronas, cantidad escogida por la aproximación a las inputs que tenemos de nuestros datos. Definimos 3 capas densas ocultas con 30, 20 y 10 neuronas respectivamente, cantidad escogida en base a las neuronas de entrada, para acercarnos a nuestra capa de salida que contiene 1 neurona. Entre capas aplicamos regularización para disminuir problemas de sobreajuste con _'Dropout'_ del 50%.
#
# Finalmente, presentamos la arquitectura de la red neuronal, como se observa en el siguiente cuadro de codigo:

# %%
# Celda 3
K.clear_session()

# Definición red neuronal con la función Sequential()
model_nn_multi5 = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
# Se definen 3 capas internas con 30 neuronas, 20 y 10 neuronas respectivamente y entre ellas realizamos un dropout
# del 50% de regularización para reducir problemas de sobreajuste.
model_nn_multi5.add(Dense(10, input_shape=(dims,),activation='relu'))
model_nn_multi5.add(Dropout(0.5))
model_nn_multi5.add(Dense(30,activation='relu'))
model_nn_multi5.add(Dropout(0.5))
model_nn_multi5.add(Dense(20,activation='relu'))
model_nn_multi5.add(Dropout(0.5))
model_nn_multi5.add(Dense(10,activation='relu'))
model_nn_multi5.add(Dropout(0.5))
model_nn_multi5.add(Dense(output_var))
model_nn_multi5.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model_nn_multi5.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                80
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 30)                330
#
#  dropout_1 (Dropout)         (None, 30)                0
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dropout_2 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 10)                210
#
#  dropout_3 (Dropout)         (None, 10)                0
#
#  dense_4 (Dense)             (None, 1)                 11
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 1,251
# Trainable params: 1,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# A continuación, definimos el optimizador de tipo **_'adam'_** ya que investigando encontramos que este optimizador combina el método de descenso del gradiente estocastico (SGD) utilizado en los puntos anteriores con adaptaciones de tasa de aprendizaje lo cual consideramos que podria darnos un entrenamiento más eficiente.
#
# Definimos la funcion de perdida con **MSE** como metrica. Aplicamos una funcion de **_'EarlyStopping'_** que monitorea la funcion de perdida y definimos el argumento **_'patiente=10'_** para indicarle a la red que se detenga si el valor de perdida no cambia en un maximo de 10 epocas.
#
# Realizamos ademas una sub-separacion de datos, utilizando los datos de entrenamiento y sacando unos datos de validacion con los que presentaremos el grafico de comportamiento de **MSE vs epocas**.
#
# Finalmente realizamos iterativamente pruebas con varias cantidades de epocas y encontramos que el algoritmo llega a un patron de estabilizacion con alrededor **200 epocas**.

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model_nn_multi5.compile(optimizer='adam', loss='mean_squared_error')

# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')

# Sub-Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_trainn, X_val, Y_trainn, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# Entrenamiento de la red neuronal con 200 épocas
model_nn_multi5.fit(X_trainn, Y_trainn,
          validation_data = (X_val, Y_val),
          epochs=200, 
          callbacks=[PlotLossesKeras(), early_stop])
# Out:
# Loss
# 	training         	 (min:    0.028, max:    0.519, cur:    0.028)
# 	validation       	 (min:    0.023, max:    0.579, cur:    0.023)
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0282 - val_loss: 0.0234
# Epoch 87: early stopping

# %% [markdown]
# Observamos que en la epoca 171 nuestra funcion de **_'EarlyStopping'_** optimizo la ejecución e identifico que los valores de MSE no cambiaron en 10 epocas consecutivas, lo cual indica que se llego a la estabilizaión del modelo y no es necesario continuar avanzando en las epocas siguientes.
#
# El modelo nos entrega entonces los siguientes valores:

# %%
# Obtener las predicciones en el conjunto de test
y_pred = model_nn_multi5.predict(X_test)
mse_nn_multi5 = mean_squared_error(Y_test, y_pred)   
mae_nn_multi5 = mean_absolute_error(Y_test, y_pred)   
print(f"MSE: {mse_nn_multi5:.4f} \nMAE: {mae_nn_multi5:.4f}")
# Out:
# 5/5 [==============================] - 0s 3ms/step
# MSE: 0.0216
# MAE: 0.1199

# %% [markdown]
# Lo que nos muestra un indice de sobreajuste adecuado o bajo, ya que aunque ambos **MSE** (el presentado en la grafica arriba como **_'val_loss'_** y el **'MSE'**) no son iguales tampoco son muy lejanos, dando a entender que la configuracion de la red neuronal tiene un muy buen comportamiento con datos completamente nuevos.
#
# ### Segunda configuración pero esta vez graficando la funcion de perdida en base al MAE (Error Medio Absoluto)
#
# Esta configuración es exactamente igual a la anterior, pero cambia en que la función de perdida esta vez está calculada con el **_'Error Medio Absoluto'_**.

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model_nn_multi5_b = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
# Se definen 2 capas internas con 30 neuronas, 20 y 10 neuronas respectivamente y entre ellas realizamos un dropout
# del 50% de regularización para reducir problemas de sobreajuste.
model_nn_multi5_b.add(Dense(10, input_shape=(dims,),activation='relu'))
model_nn_multi5_b.add(Dropout(0.5))
model_nn_multi5_b.add(Dense(30,activation='relu'))
model_nn_multi5_b.add(Dropout(0.5))
model_nn_multi5_b.add(Dense(20,activation='relu'))
model_nn_multi5_b.add(Dropout(0.5))
model_nn_multi5_b.add(Dense(10,activation='relu'))
model_nn_multi5_b.add(Dropout(0.5))
model_nn_multi5_b.add(Dense(output_var))
model_nn_multi5_b.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model_nn_multi5_b.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                80
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 30)                330
#
#  dropout_1 (Dropout)         (None, 30)                0
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dropout_2 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 10)                210
#
#  dropout_3 (Dropout)         (None, 10)                0
#
#  dense_4 (Dense)             (None, 1)                 11
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 1,251
# Trainable params: 1,251
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Definición de función de perdida. Se usa mean_absolute_error dado que es un ejercicio de regresión
model_nn_multi5_b.compile(optimizer='adam', loss='mae')

# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')

# Sub-Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_trainn, X_val, Y_trainn, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# Entrenamiento de la red neuronal con 200 épocas
model_nn_multi5_b.fit(X_trainn, Y_trainn,
          validation_data = (X_val, Y_val),
          epochs=200, 
          callbacks=[PlotLossesKeras(), early_stop])
# Out:
# Loss
# 	training         	 (min:    0.113, max:    0.674, cur:    0.116)
# 	validation       	 (min:    0.110, max:    0.540, cur:    0.112)
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1164 - val_loss: 0.1120
# Epoch 101: early stopping

# %% [markdown]
# Observamos que en la epoca 146 nuestra funcion de 'EarlyStopping' optimizo la ejecución e identifico que los valores de MSE no cambiaron en 10 epocas consecutivas, lo cual indica que se llego a la estabilizaión del modelo y no es necesario continuar avanzando en las epocas siguientes.
#
# El modelo nos entrega entonces los siguientes valores:

# %%
# Obtener las predicciones en el conjunto de test
y_pred = model_nn_multi5_b.predict(X_test)
mse_nn_multi5_b = mean_squared_error(Y_test, y_pred)   
mae_nn_multi5_b = mean_absolute_error(Y_test, y_pred)   
print(f"MSE con el set de test: {mse_nn_multi5_b:.4f} \nMAE con el set de test: {mae_nn_multi5_b:.4f}")
# Out:
# 5/5 [==============================] - 0s 1ms/step
# MSE con el set de test: 0.0190
# MAE con el set de test: 0.1112

# %% [markdown]
# Lo que nos muestra un indice de sobreajuste adecuado o bajo, ya que aunque ambos **MSE** (el presentado en la grafica arriba como **_'val_loss'_** y el **'MSE'**) no son iguales tampoco son muy lejanos, dando a entender que la configuracion de la red neuronal tiene un muy buen comportamiento con datos completamente nuevos.

# %% [markdown]
# ## Punto 4 - Comparación y análisis de resultados
#
# En la celda 4 comparen los resultados obtenidos de las diferentes redes y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 4
# Comparando Resultados
etiquetas = ['Unicapa', 'Multicapa (2)', 'Multicapa (5)']
valores_mse = [mse_nn_unicapa2, mse_nn_multi2_reg, mse_nn_multi5_b]
valores_mse = [round(x, 3) for x in valores_mse]

valores_mae = [mae_nn_unicapa2, mae_nn_multi2_reg, mae_nn_multi5_b]
valores_mae = [round(x, 3) for x in valores_mae]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

ax1.bar(etiquetas, valores_mse)
for i in range(len(valores_mse)):
    ax1.text(i, valores_mse[i], valores_mse[i], ha='center', va='bottom')
ax1.set_title('Comparacion de Resultados MSE')
ax1.set_xlabel(30*'-' + ' Red Neuronal ' + 30*'-')
ax1.set_ylabel('MSE')
ax1.set_xticks(range(len(etiquetas)))
ax1.set_xticklabels(etiquetas, rotation=0)

ax2.bar(etiquetas, valores_mae)
for i in range(len(valores_mae)):
    ax2.text(i, valores_mae[i], valores_mae[i], ha='center', va='bottom')
ax2.set_title('Comparacion de Resultados MAE')
ax2.set_xlabel(30*'-' + ' Red Neuronal ' + 30*'-')
ax2.set_ylabel('MAE')
ax2.set_xticks(range(len(etiquetas)))
ax2.set_xticklabels(etiquetas, rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Para este problema el modelo de una sólo capa tiene el mejor desempeño, además de los resultados este modelo es rápido de entrenar y sencillo de configurar. La clave es encontrar la combinación de parámetros adecuados, tales como añadir funciones de early stopping, escoger correctamente la función de activación de acuerdo a la salida y definir optimizadores adecuados como por ejemplo el SGD. Por lo tanto, para este set de datos recomendamos el uso de redes neuronales de una sola capa.
#
# Es preciso anotar que dado que las redes neuronales son muy propensas a usar caer en overfitting, este se combatió, por ejemplo, agregando términos de regularización a las capas ocultas (regularización), desactivando algunas neuronaes (dropout) y ajustando los hiperparámetros. El método que se usó para el modelo de 1 capa y multicapa fue subdividiendo la muestra entrenamiento en otra muestra de validación, mientras que para el modelo de 2 capas el de regularización fue más efectivo.
#
# Las redes neuronales Multicapa por su naturaleza incrementan el tiempo de entrenamiento y se evidencia en la velocidad en la que el modelo unicapa termina versus los otros. Adicionalmente a eso, los cambios de la función de costos tienden a ser menos estables y con más picos que los unicapa. Por tal razón las funciones de early stopping nos permiten detener el entrenamiento cuando esté alcance una estabilidad (no se presentan cambios en la fn de costos) en base a las épocas. Cómo este trabajo es un proceso iterativo incrementando o reduciendo las épocas de entrenamiento, funciones cómo estás ahorran tiempo y procesamiento de cómputo.
